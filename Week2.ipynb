# %% [markdown]
# <a href="https://colab.research.google.com/github/afipolinema/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# STEP 1

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
afi=cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kOCING1.jpg')
plt.imshow(afi)

# %% [markdown]
# STEP 2

# %%
afi2=afi
afi3=cv.cvtColor(afi,cv.COLOR_BGR2RGB)
plt.imshow(afi3)

# %% [markdown]
# STEP 3

# %%
afi_gray=cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kOCING1.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(afi_gray)

# %% [markdown]
# STEP 4

# %%
plt.imshow(afi_gray, cmap='gray')

# %% [markdown]
# STEP 5
