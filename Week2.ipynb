# %% [markdown]
# <a href="https://colab.research.google.com/github/afipolinema/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# STEP 1

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
afi=cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
plt.imshow(afi)

# %% [markdown]
# STEP 2

# %%
afi2=afi
afi3=cv.cvtColor(afi,cv.COLOR_BGR2RGB)
plt.imshow(afi3)

# %% [markdown]
# STEP 3

# %%
afi_gray=cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(afi_gray)

# %% [markdown]
# STEP 4

# %%
plt.imshow(afi_gray, cmap='gray')

# %% [markdown]
# STEP 5

# %%
plt.imshow(afi_gray, cmap='magma')

# %% [markdown]
# STEP 6

# %%
afi4= cv.resize(cv.cvtColor(afi,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(afi4)

# %% [markdown]
# STEP 7

# %%
afi5=cv.flip(cv.cvtColor(afi,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ex  = fig.add_subplot(111)
ex.imshow(afi5)

# %% [markdown]
# STEP 8

# %%
black_afi = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_afi)

# %% [markdown]
# STEP 9

# %%
cv.rectangle(black_afi,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=5)
plt.imshow(black_afi)

# %% [markdown]
# STEP 10

# %%
cv.rectangle(black_afi,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=10)
plt.imshow(black_afi)

# %% [markdown]
# STEP 11

# %%
cv.circle(black_afi,center=(100,100),radius=50,color=(255,0,0),thickness=5)
plt.imshow(black_afi)

# %% [markdown]
# STEP 12

# %%
cv.line(black_afi,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_afi)

# %% [markdown]
# STEP 13

# %%
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_afi,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(black_afi)

# %% [markdown]
# STEP 14

# %%
black_afi2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_afi2)

# %% [markdown]
# STEP 15

# %%
vertices=np.array([[100,300],
                   [200,200],
                   [400,300],
                   [200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# STEP 16

# %%
pts=vertices.reshape((-1,1,2))#fungsi reshape adalah mengubah bentuk array tanpa mengubah data
pts#dimana pada kasus ini data data akan dibentuk menjadi per kolom menambahkan kurung siku
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# STEP 17

# %%
cv.polylines(black_afi2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_afi2)

# %% [markdown]
# TUGAS

# %%
#Tugas2 afi
plt.imshow(afi_gray,cmap='RdYlGn')

# %%
plt.imshow(afi_gray,cmap='GnBu')

# %%
#Tugas3 afi
#Menampilkan image baris ke 20-115, kolom 25-120!
plt.imshow(afi3)

# %%
plt.imshow(afi3[20:115,25:120])

# %%
#Tugas4 afi
plt.imshow(afi_gray,cmap='Blues')

# %%
plt.imshow(afi_gray[5:30])

# %%
#Tugas5 afi
#Membuat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.disarankan menggunakan bilangan acak/random!
t=afi.shape[0]
l=afi.shape[1]
print("t = ",t,"l = ",l)
# Out:
# t =  213 l =  237

# %%
#Tugas5 afi
img5 = cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
img5 = cv.cvtColor(img5,cv.COLOR_BGR2RGB)
cv.rectangle(img5, pt1=(300,300), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img5, pt1=(500,100), pt2=(400,200), color=(0,255,0),thickness=10)
cv.rectangle(img5, pt1=(400,400), pt2=(500,300), color=(255,255,255),thickness=10)
cv.rectangle(img5, pt1=(100,200), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img5, pt1=(150,300), pt2=(300,150), color=(0,0,255),thickness=10)
plt.imshow(img5)

# %%
#Tugas6 afi
img5 = cv.flip(cv.cvtColor(img5, cv.COLOR_BGR2RGB), 0)
plt.imshow(img5)

# %%
#Tugas7 afi
img9 = cv.imread('/content/drive/MyDrive/PCVK WEEK 2/Foto pribadi.jpeg')
img10 = cv.cvtColor(img9, cv.COLOR_BGR2RGB)
cv.circle(img10, (375,180), 200, (255,0,0), 5)
cv.rectangle(img10, (600,0), (150,350), (0,255,0), 5)
plt.imshow(img10)

# %%
#8Tugas8 afi
img11 = cv.imread('/content/drive/MyDrive/PCVK WEEK 2/Foto pribadi.jpeg')
plt.imshow(img11)

#Menjadikan warna RGB
img_rgb = cv.cvtColor(img11,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# Membuat rectangle pada bagian sudut kiri bawah
cv.rectangle(img_rgb,pt1=(150,450),pt2=(15,500),color=(0,0,255),thickness=10)
plt.imshow(img_rgb)

# %%
#Tugas9 afi
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(img_rgb,text='afi',org=(350,500),fontFace=font,fontScale=4,color=(0,255,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(img_rgb)

# %%
afi = cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
plt.imshow(afi)

# %%
afi
afi = cv.cvtColor(afi,cv.COLOR_BGR2RGB)
plt.imshow (afi)

# %%
rb = plt.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
plt.imshow(rb)

# %%
afi = cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
afi = cv.cvtColor(afi,cv.COLOR_BGR2RGB)
R,G,B = cv.split(afi)

zeros = np.zeros(afi.shape[:2],dtype ="uint8")
r = cv.merge([R, zeros, zeros])

plt.imshow(r)

# %%
g = cv.merge([zeros, G, zeros])
plt.imshow(g)

# %%
b = cv.merge([zeros, zeros, B])
plt.imshow(b)

# %%
afi = cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
cv2_imshow(afi)
# Out:
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7F757B13EEB0>

# %%
afi = plt.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
plt.imshow(afi)

# %%
afi = cv.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
plt.imshow(afi)

# %%
afi = plt.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
cv2.imshow(afi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-2fbd4a0f77b6> in <module>
#       1 afi = plt.imread('/content/drive/MyDrive/PCVK WEEK 2/kitten.jpeg')
# ----> 2 cv2.imshow(afi)
#
# NameError: name 'cv2' is not defined
